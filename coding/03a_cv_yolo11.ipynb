# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 19.3 MB/s eta 0:00:00
# ...

# %%
import os
import shutil
import torch
from ultralytics import YOLO
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
os.makedirs("/content/drive/MyDrive/YOLO11Best", exist_ok=True)

# %%
# !ls /content/drive/MyDrive/
# Out:
#  02_Kickstarter_regresione_logistica_lumping.R
# '03_Kickstarter_TREE (1).pdf'
#  03_Kickstarter_tree.R
#  04_Kickstarter_KNN.Rmd
#  ada_boost_100_3alberi.pdf
#  ada_boost_100_alberi_4.pdf
#  ada_boost_150_alberi_3.pdf
# 'ada_boost_50_3__alberi (1).pdf'
#  ada_boost_50_3__alberi.pdf
#  ADA_BOOST_THE_BEST.pdf
# 'Analisi Bandi Italiani'
# 'Colab Notebooks'
# 'Copia di EDB01_06_testi_e_soluzioni.gdoc'
# 'Copia di sentence_transformers.ipynb'
# 'Disegno senza titolo (1).gdraw'
# 'Disegno senza titolo.gdraw'
#  goal_distribution.pdf
#  goal_usd_x_progetti.pdf
# 'importanza (2).jpg'
#  Kickstarter_2024-12-12T03_20_04_455Z
#  Kickstarter_2024-12_rewards_dicotomico_30000-33000.csv
# 'Kickstarter_Machine Learning'
#  KNN
#  max_outliers.pdf
#  min_outlierl.pdf
#  nr_progetti_country.pdf
#  old_codici
#  OUTLIERS
#  produce_merged_csv.py
#  RANDOM_FOREST.Rmd
#  Rplot10.pdf
#  Rplot_IMPORTANZA_VARIABILI.pdf
#  Rplot_nr_sottocategorie_x_categorie.pdf
#  var_outlier.pdf
# ...

# %%
data_yaml_path = "/content/drive/MyDrive/YOLO11/data.yaml"

# %%
device = "cuda" if torch.cuda.is_available() else "cpu"
device
# Out:
# 'cuda'

# %%
model = YOLO("yolo11n.yaml")

# %%
train_results = model.train(
    data=data_yaml_path,
    epochs=100,
    imgsz=640,
    batch=8,
    optimizer="Adam",
    device=0,
    workers=2,
    patience=20000,
    save_period=20,
    plots=True
)

import shutil

src = "runs/detect/train/weights/best.pt"
dst = "/content/drive/MyDrive/YOLO11Best/best_yolo11.pt"
shutil.copy(src, dst)

print("Modello salvato su Drive!")
# Out:
# Ultralytics 8.3.232 🚀 Python-3.12.12 torch-2.9.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
val = model.val()
print(" METRICHE VALIDATION")
print(f"Precision        : {val.results_dict['metrics/precision(B)']:.3f}")
print(f"Recall           : {val.results_dict['metrics/recall(B)']:.3f}")
print(f"mAP50            : {val.results_dict['metrics/mAP50(B)']:.3f}")
print(f"mAP50-95         : {val.results_dict['metrics/mAP50-95(B)']:.3f}")
# Out:
# Ultralytics 8.3.232 🚀 Python-3.12.12 torch-2.9.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# YOLO11n summary (fused): 100 layers, 2,584,102 parameters, 0 gradients, 6.3 GFLOPs
# val: Fast image access ✅ (ping: 0.5±0.2 ms, read: 9.3±4.7 MB/s, size: 16.7 KB)
# val: Scanning /content/drive/MyDrive/YOLO11/valid/labels.cache... 615 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 615/615 692.7Kit/s 0.0s
# WARNING ⚠️ Box and segment counts should be equal, but got len(segments) = 8, len(boxes) = 1208. To resolve this only boxes will be used and all segments will be removed. To avoid this please supply either a detect or segment dataset, not a detect-segment mixed dataset.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 39/39 3.7it/s 10.6s
#                    all        615       1208      0.886      0.865      0.925      0.649
#                    APC         56        115      0.882      0.845        0.9      0.594
# ...
